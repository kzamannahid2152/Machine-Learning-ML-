# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science/(Week_13_14_15_16_17) Machine Learning (ML)/insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.xlabel('age')
plt.ylabel('bought insurance')
plt.scatter(df.age,df.bought_insurance, marker='+', color='red')

# %%
from sklearn.model_selection import train_test_split
# model = LogisticRegression()

# %%
X = df[['age']]
y = df[['bought_insurance']]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
X_train
# Out:
#     age
# 26   23
# 7    60
# 6    55
# 19   18
# 8    62
# 25   54
# 15   55
# 14   49
# 10   18
# 0    22
# 16   25
# 20   21
# 23   45
# 21   26
# 4    46
# 22   40
# 17   58
# 11   28
# 18   19
# 3    52
# 12   27

# %%
X_test
# Out:
#     age
# 1    25
# 9    61
# 5    56
# 13   29
# 2    47
# 24   50

# %%
y_train
# Out:
#     bought_insurance
# 26                 0
# 7                  1
# 6                  0
# 19                 0
# 8                  1
# 25                 1
# 15                 1
# 14                 1
# 10                 0
# 0                  0
# 16                 1
# 20                 0
# 23                 1
# 21                 0
# 4                  1
# 22                 1
# 17                 1
# 11                 0
# 18                 0
# 3                  0
# 12                 0

# %%
y_test
# Out:
#     bought_insurance
# 1                  0
# 9                  1
# 5                  1
# 13                 0
# 2                  1
# 24                 1

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
X_train
# Out:
#     age
# 26   23
# 7    60
# 6    55
# 19   18
# 8    62
# 25   54
# 15   55
# 14   49
# 10   18
# 0    22
# 16   25
# 20   21
# 23   45
# 21   26
# 4    46
# 22   40
# 17   58
# 11   28
# 18   19
# 3    52
# 12   27

# %%
X_test
# Out:
#     age
# 1    25
# 9    61
# 5    56
# 13   29
# 2    47
# 24   50

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.score(X_train,y_train)
# Out:
# 0.8571428571428571

# %%
X_test
# Out:
#     age
# 1    25
# 9    61
# 5    56
# 13   29
# 2    47
# 24   50

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1, 0, 1, 1])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.83991065, 0.16008935],
#        [0.0806211 , 0.9193789 ],
#        [0.13404309, 0.86595691],
#        [0.76904954, 0.23095046],
#        [0.30094571, 0.69905429],
#        [0.23437736, 0.76562264]])
